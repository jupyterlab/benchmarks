# %%
from IPython.display import display
def Table(data=''):
    bundle = {}
    bundle['text/csv'] = data
    display(bundle, raw=True)
    
example_data = '\n'.join(';'.join([str(x) for x in range(50)]) for y in range(200))

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)

# %%
Table(example_data)
