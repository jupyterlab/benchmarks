# %%
from IPython.display import HTML

HTML(f'<div>{"".join("<div>I am a long string in a div which is repeatedly added to one html object: %d</div>" % i for i in range(1500))}</div>')
# Out:
# <div><div>I am a long string in a div which is repeatedly added to one html object: 0</div><div>I am a long string in a div which is repeatedly added to one html object: 1</div><div>I am a long string in a div which is repeatedly added to one html object: 2</div><div>I am a long string in a div which is repeatedly added to one html object: 3</div><div>I am a long string in a div which is repeatedly added to one html object: 4</div><div>I am a long string in a div which is repeatedly added to one html object: 5</div><div>I am a long string in a div which is repeatedly added to one html object: 6</div><div>I am a long string in a div which is repeatedly added to one html object: 7</div><div>I am a long string in a div which is repeatedly added to one html object: 8</div><div>I am a long string in a div which is repeatedly added to one html object: 9</div><div>I am a long string in a div which is repeatedly added to one html object: 10</div><div>I am a long string in a div which is repe
# ...
